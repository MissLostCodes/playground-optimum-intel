# %% [markdown]
# ## Older version

# %%
# !pip install sentence-transformers -q

# %%
from sentence_transformers import SentenceTransformer

# %%
dir(SentenceTransformer)
# Out:
# ['T_destination',
#  '__add__',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_call_impl',
#  '_compiled_call_impl',
#  '_create_model_card',
#  '_encode_multi_process',
#  '_encode_multi_process_worker',
#  '_eval_during_training',
#  '_first_module',
#  '_get_backward_hooks',
#  '_get_backward_pre_hooks',
#  '_get_item_by_idx',
#  '_get_model_type',
#  '_get_name',
# ...

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
texts = ["hello world"]
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
if hasattr(model, "_text_length"):
    print("text_length:", model._text_length(texts))
else:
    print("_text_length not available")

if hasattr(model, "_input_length"):
    print("input_length:", model._input_length(texts))
else:
    print("_input_length not available")

print("max_seq_length:", model.max_seq_length)
# Out:
# text_length: 11
# _input_length not available
# max_seq_length: 256

# %% [markdown]
# Has _text_length

# %% [markdown]
# ## Upgraded sentence transformer

# %%
# !pip install -U sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.8/570.8 kB 11.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 5.3.0
#     Uninstalling sentence-transformers-5.3.0:
#       Successfully uninstalled sentence-transformers-5.3.0
# ...

# %%
from sentence_transformers import SentenceTransformer
dir(SentenceTransformer)
# Out:
# ['T_destination',
#  '__abstractmethods__',
#  '__add__',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_apply',
#  '_call_impl',
#  '_can_flatten_inputs',
#  '_compiled_call_impl',
#  '_create_model_card',
#  '_default_prompts',
#  '_eval_during_training',
#  '_first_module',
#  '_get_backward_hooks',
#  '_get_backward_pre_hooks',
# ...

# %%
model = SentenceTransformer("all-MiniLM-L6-v2")
texts = ["hello world"]
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
if hasattr(model, "_text_length"):
    print("text_length:", model._text_length(texts))
else:
    print("_text_length not available")

if hasattr(model, "_input_length"):
    print("input_length:", model._input_length(texts))
else:
    print("_input_length not available")

print("max_seq_length:", model.max_seq_length)
# Out:
# _text_length not available
# input_length: 11
# max_seq_length: 256

# %% [markdown]
# no _text_length supported and _input_length introduced

# %% [markdown]
# ## Testing fix

# %%
# !pip install -U pip
# !pip install -U transformers sentence-transformers datasets
# !pip install openvino openvino-dev

# %%
# !pip install git+https://github.com/MissLostCodes/optimum-intel.git@fix/sentence-transformer-text-length-v2
# Out:
# ...
#   Cloning https://github.com/MissLostCodes/optimum-intel.git (to revision fix/sentence-transformer-text-length-v2) to /tmp/pip-req-build-j1ak1_hz
#   Running command git clone --filter=blob:none --quiet https://github.com/MissLostCodes/optimum-intel.git /tmp/pip-req-build-j1ak1_hz
#   Running command git checkout -b fix/sentence-transformer-text-length-v2 --track origin/fix/sentence-transformer-text-length-v2
#   Switched to a new branch 'fix/sentence-transformer-text-length-v2'
#   Branch 'fix/sentence-transformer-text-length-v2' set up to track remote branch 'fix/sentence-transformer-text-length-v2' from 'origin'.
#   Resolved https://github.com/MissLostCodes/optimum-intel.git to commit b1d51c8772dcc67e813d74b19d29282136f652f5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
import optimum

# %%
# !optimum-cli export openvino \
  --task feature-extraction \
  --model optimum-intel-internal-testing/stsb-bert-tiny-safetensors \
  --quant-mode int8 \
  --library sentence_transformers \
  --dataset c4 \
  --num-samples 1 \
  ov_model
# Out:
# 2026-04-13 17:59:42.204159: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-13 17:59:42.713962: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-13 17:59:43.028836: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776103183.392681   26531 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776103183.496282   26531 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
