# %%
# !pip install -U pip
# !pip install -U transformers sentence-transformers datasets
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 27.6 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-26.0.1
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Collecting transformers
#   Downloading transformers-5.5.4-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.3.0)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.4.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Collecting datasets
#   Downloading datasets-4.8.4-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.10.0+cu128)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.3)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Downloading pyarrow-23.0.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.1 kB)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets) (2.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.11.0->sentence-transformers) (1.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Downloading transformers-5.5.4-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 26.7 MB/s  0:00:00
# Downloading sentence_transformers-5.4.0-py3-none-any.whl (570 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.8/570.8 kB 26.2 MB/s  0:00:00
# Downloading datasets-4.8.4-py3-none-any.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 24.2 MB/s  0:00:00
# Downloading pyarrow-23.0.1-cp312-cp312-manylinux_2_28_x86_64.whl (47.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 46.3 MB/s  0:00:01
# Installing collected packages: pyarrow, datasets, transformers, sentence-transformers
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/4 [pyarrow]

# %%
# !pip install git+https://github.com/huggingface/optimum-intel.git
# Out:
# Collecting git+https://github.com/huggingface/optimum-intel.git
#   Cloning https://github.com/huggingface/optimum-intel.git to /tmp/pip-req-build-b156e5dr
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/optimum-intel.git /tmp/pip-req-build-b156e5dr
#   Resolved https://github.com/huggingface/optimum-intel.git to commit 1802051c169847fa893f621f3e0f5524ac7553c9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.12/dist-packages (from optimum-intel==1.27.0.dev0+1802051) (2.10.0+cu128)
# Collecting optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main (from optimum-intel==1.27.0.dev0+1802051)
#   Cloning https://github.com/huggingface/optimum-onnx.git (to revision main) to /tmp/pip-install-qhqh2wbw/optimum-onnx_9d3f02f779b649dea7fe49d0386918c5
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/optimum-onnx.git /tmp/pip-install-qhqh2wbw/optimum-onnx_9d3f02f779b649dea7fe49d0386918c5
#   Resolved https://github.com/huggingface/optimum-onnx.git to commit 3b33f43398b4e191a993474b8cfadc11d8e01ff2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting transformers<4.58,>=4.45 (from optimum-intel==1.27.0.dev0+1802051)
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from optimum-intel==1.27.0.dev0+1802051) (75.2.0)
# Collecting nncf>=2.19.0 (from optimum-intel==1.27.0.dev0+1802051)
#   Downloading nncf-3.1.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting openvino>=2025.4.0 (from optimum-intel==1.27.0.dev0+1802051)
#   Downloading openvino-2026.1.0-21367-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (12 kB)
# Collecting openvino-tokenizers>=2025.4.0 (from optimum-intel==1.27.0.dev0+1802051)
#   Downloading openvino_tokenizers-2026.1.0.0-py3-none-manylinux_2_28_x86_64.whl.metadata (27 kB)
# Collecting optimum @ git+https://github.com/huggingface/optimum (from optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051)
#   Cloning https://github.com/huggingface/optimum to /tmp/pip-install-qhqh2wbw/optimum_4a70aed8cab64fd588bc0755a92e5e39
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/optimum /tmp/pip-install-qhqh2wbw/optimum_4a70aed8cab64fd588bc0755a92e5e39
#   Resolved https://github.com/huggingface/optimum to commit 3db78a41a715a04d4629e21cec4e7b1790c8266f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting onnx (from optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051)
#   Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Collecting onnxscript (from optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051)
#   Downloading onnxscript-0.6.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from optimum @ git+https://github.com/huggingface/optimum->optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051) (26.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optimum @ git+https://github.com/huggingface/optimum->optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051) (2.0.2)
# Requirement already satisfied: huggingface_hub>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from optimum @ git+https://github.com/huggingface/optimum->optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051) (1.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<4.58,>=4.45->optimum-intel==1.27.0.dev0+1802051) (3.25.2)
# Collecting huggingface_hub>=0.8.0 (from optimum @ git+https://github.com/huggingface/optimum->optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<4.58,>=4.45->optimum-intel==1.27.0.dev0+1802051) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.58,>=4.45->optimum-intel==1.27.0.dev0+1802051) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers<4.58,>=4.45->optimum-intel==1.27.0.dev0+1802051) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<4.58,>=4.45->optimum-intel==1.27.0.dev0+1802051) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<4.58,>=4.45->optimum-intel==1.27.0.dev0+1802051) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers<4.58,>=4.45->optimum-intel==1.27.0.dev0+1802051) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum @ git+https://github.com/huggingface/optimum->optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum @ git+https://github.com/huggingface/optimum->optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051) (1.4.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.8.0->optimum @ git+https://github.com/huggingface/optimum->optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051) (4.15.0)
# Collecting networkx<3.5.0,>=2.6 (from nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting ninja<1.14,>=1.10.0.post2 (from nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting openvino-telemetry>=2023.2.0 (from nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051)
#   Downloading openvino_telemetry-2025.2.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051) (5.9.5)
# Collecting pydot<=3.0.4,>=1.4.1 (from nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051)
#   Downloading pydot-3.0.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: rich>=13.5.2 in /usr/local/lib/python3.12/dist-packages (from nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051) (13.9.4)
# Requirement already satisfied: scikit-learn>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051) (1.6.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051) (1.16.3)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051) (0.9.0)
# Requirement already satisfied: pyparsing>=3.0.9 in /usr/local/lib/python3.12/dist-packages (from pydot<=3.0.4,>=1.4.1->nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.5.2->nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.5.2->nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.5.2->nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.0->nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.24.0->nncf>=2.19.0->optimum-intel==1.27.0.dev0+1802051) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (1.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1->optimum-intel==1.27.0.dev0+1802051) (3.0.3)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx->optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051) (5.29.6)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx->optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051) (0.5.4)
# Collecting onnx_ir<2,>=0.1.15 (from onnxscript->optimum-onnx @ git+https://github.com/huggingface/optimum-onnx.git@main->optimum-intel==1.27.0.dev0+1802051)
#   Downloading onnx_ir-0.2.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.58,>=4.45->optimum-intel==1.27.0.dev0+1802051) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.58,>=4.45->optimum-intel==1.27.0.dev0+1802051) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.58,>=4.45->optimum-intel==1.27.0.dev0+1802051) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers<4.58,>=4.45->optimum-intel==1.27.0.dev0+1802051) (2026.2.25)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 28.5 MB/s  0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 28.0 MB/s  0:00:00
# Downloading nncf-3.1.0-py3-none-any.whl (805 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.6/805.6 kB 33.0 MB/s  0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 50.4 MB/s  0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
# Downloading pydot-3.0.4-py3-none-any.whl (35 kB)
# Downloading openvino-2026.1.0-21367-cp312-cp312-manylinux_2_28_x86_64.whl (56.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 MB 69.9 MB/s  0:00:00
# Downloading openvino_telemetry-2025.2.0-py3-none-any.whl (25 kB)
# Downloading openvino_tokenizers-2026.1.0.0-py3-none-manylinux_2_28_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 100.9 MB/s  0:00:00
# Downloading onnx-1.21.0-cp312-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 151.1 MB/s  0:00:00
# Downloading onnxscript-0.6.2-py3-none-any.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 34.4 MB/s  0:00:00
# Downloading onnx_ir-0.2.0-py3-none-any.whl (164 kB)
# Building wheels for collected packages: optimum-intel, optimum-onnx, optimum
#   Building wheel for optimum-intel (pyproject.toml) ... done
#   Created wheel for optimum-intel: filename=optimum_intel-1.27.0.dev0+1802051-py3-none-any.whl size=391088 sha256=c7c0dd848e43f706fc0b23e89cbd5f1c0a87dcfbd6cf097ba254b2f38554ab5e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sol5bh_g/wheels/3e/28/37/922d7ce51fa59781a14b4187a13184af5a1d19da8b80d59adb
#   Building wheel for optimum-onnx (pyproject.toml) ... done
#   Created wheel for optimum-onnx: filename=optimum_onnx-0.1.0.dev0-py3-none-any.whl size=198217 sha256=1b88fbaab0b93c875871630265da5dacaf73809ba9a050cda3bf838858608581
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sol5bh_g/wheels/f0/bb/0e/8f13d46f850db0748ed4f8c61e63666f191289611d43a93dc0
#   Building wheel for optimum (pyproject.toml) ... done
#   Created wheel for optimum: filename=optimum-2.1.0.dev0-py3-none-any.whl size=161343 sha256=67029c0a035bf1e1e412deea8d6d721586425ed954b5e1e4ba8924ca38f13683
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sol5bh_g/wheels/4a/c7/72/f0a71f75076bac382ef01cf2f8ae694d709b39641555fd36e0
# Successfully built optimum-intel optimum-onnx optimum
# Installing collected packages: openvino-telemetry, pydot, openvino, ninja, networkx, openvino-tokenizers, onnx, huggingface_hub, onnx_ir, nncf, transformers, onnxscript, optimum, optimum-onnx, optimum-intel
#   Attempting uninstall: pydot
#     Found existing installation: pydot 4.0.1
#     Uninstalling pydot-4.0.1:
#       Successfully uninstalled pydot-4.0.1
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.6.1
#     Uninstalling networkx-3.6.1:
#       Successfully uninstalled networkx-3.6.1
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.8.0
#     Uninstalling huggingface_hub-1.8.0:
#       Successfully uninstalled huggingface_hub-1.8.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.5.4
#     Uninstalling transformers-5.5.4:
#       Successfully uninstalled transformers-5.5.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [optimum-intel]
# Successfully installed huggingface_hub-0.36.2 networkx-3.4.2 ninja-1.13.0 nncf-3.1.0 onnx-1.21.0 onnx_ir-0.2.0 onnxscript-0.6.2 openvino-2026.1.0 openvino-telemetry-2025.2.0 openvino-tokenizers-2026.1.0.0 optimum-2.1.0.dev0 optimum-intel-1.27.0.dev0+1802051 optimum-onnx-0.1.0.dev0 pydot-3.0.4 transformers-4.57.6

# %%
# !optimum-cli export openvino \
  --task feature-extraction \
  --model optimum-intel-internal-testing/stsb-bert-tiny-safetensors \
  --quant-mode int8 \
  --library sentence_transformers \
  --dataset c4 \
  --num-samples 1 \
  ov_model
# Out:
# 2026-04-13 18:35:43.236445: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776105343.271480    2640 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776105343.282891    2640 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776105343.310106    2640 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776105343.310138    2640 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776105343.310143    2640 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776105343.310150    2640 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-13 18:35:43.317190: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Multiple distributions found for package optimum. Picked distribution: optimum-intel
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# modules.json: 100% 229/229 [00:00<00:00, 1.55MB/s]
# config_sentence_transformers.json: 100% 123/123 [00:00<00:00, 1.03MB/s]
# README.md: 4.03kB [00:00, 2.52MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 374kB/s]
# config.json: 100% 622/622 [00:00<00:00, 4.28MB/s]
# model.safetensors: 100% 17.5M/17.5M [00:01<00:00, 14.2MB/s]
# tokenizer_config.json: 1.27kB [00:00, 6.45MB/s]
# vocab.txt: 232kB [00:00, 10.5MB/s]
# tokenizer.json: 712kB [00:00, 52.6MB/s]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 984kB/s]
# config.json: 100% 270/270 [00:00<00:00, 1.70MB/s]
# WARNING:sentence_transformers.base.model:`SentenceTransformer._target_device` has been deprecated. Please use `SentenceTransformer.device` instead.
# WARNING:sentence_transformers.base.model:`SentenceTransformer._target_device` has been deprecated. Please use `SentenceTransformer.device` instead.
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_attn_mask_utils.py:196: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   inverted_mask = torch.tensor(1.0, dtype=dtype) - expanded_mask
# /usr/local/lib/python3.12/dist-packages/sentence_transformers/sentence_transformer/modules/pooling.py:135: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if "attention_mask" in features and features["attention_mask"].size(-1) == token_embeddings.size(1):
# Traceback (most recent call last):
#   File "/usr/local/bin/optimum-cli", line 6, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/optimum/commands/optimum_cli.py", line 219, in main
#     service.run()
#   File "/usr/local/lib/python3.12/dist-packages/optimum/commands/export/openvino.py", line 485, in run
#     _main_quantize(
#   File "/usr/local/lib/python3.12/dist-packages/optimum/exporters/openvino/__main__.py", line 681, in _main_quantize
#     model = model_cls.from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/optimum/intel/openvino/modeling_base.py", line 613, in from_pretrained
#     return super().from_pretrained(
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/optimum/modeling_base.py", line 407, in from_pretrained
#     return from_pretrained_method(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/optimum/intel/openvino/modeling_sentence_transformers.py", line 97, in _from_pretrained
#     model = super()._from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/optimum/intel/openvino/modeling_base.py", line 534, in _from_pretrained
#     model = cls(
#             ^^^^
#   File "/usr/local/lib/python3.12/dist-packages/optimum/intel/openvino/modeling_sentence_transformers.py", line 30, in __init__
#     self._text_length = MethodType(SentenceTransformer._text_length, self)
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: type object 'SentenceTransformer' has no attribute '_text_length'. Did you mean: '_input_length'?

# %%
import sentence_transformers
print(sentence_transformers.__version__)
# Out:
# 5.4.0
