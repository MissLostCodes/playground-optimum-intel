# %%
# !pip install openvino openvino-dev
# !pip install parameterized
# !pip install timm pillow
# !pip install openvino-genai
# !pip install open-clip-torch
# !pip install -U transformers
# Out:
# ...
#   Using cached openvino-2026.1.0-21367-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (12 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 20.0 MB/s  0:00:00
# Using cached openvino-2026.1.0-21367-cp312-cp312-manylinux_2_28_x86_64.whl (56.8 MB)
# ...
#   Attempting uninstall: openvino
#     Found existing installation: openvino 2024.6.0
#     Uninstalling openvino-2024.6.0:
#       Successfully uninstalled openvino-2024.6.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openvino-genai]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# optimum-intel 1.27.0.dev0+07e3dd4 requires transformers<4.58,>=4.45, but you have transformers 5.7.0 which is incompatible.
# openvino-dev 2024.6.0 requires openvino==2024.6.0, but you have openvino 2026.1.0 which is incompatible.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.7 MB/s  0:00:00
# ...

# %%
# !pip install transformers_stream_generator

# %%
# !git clone https://github.com/MissLostCodes/optimum-intel.git
# %cd optimum-intel
# !git checkout fix/openvino-respect-trust-remote-code
# Out:
# fatal: destination path 'optimum-intel' already exists and is not an empty directory.
# /content/optimum-intel
# M	tests/openvino/test_export.py
# Already on 'fix/openvino-respect-trust-remote-code'
# Your branch is up to date with 'origin/fix/openvino-respect-trust-remote-code'.

# %%
# !pip install -U pip
# !pip install -e .[dev]
# Out:
# ...
# Obtaining file:///content/optimum-intel
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/optimum-onnx.git (to revision main) to /tmp/pip-install-dfrk_24m/optimum-onnx_822e26b963254be99fd6fa5493d61141
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/optimum-onnx.git /tmp/pip-install-dfrk_24m/optimum-onnx_822e26b963254be99fd6fa5493d61141
#   Resolved https://github.com/huggingface/optimum-onnx.git to commit 1939f27a1d04bd9fdf4c3b17eaa70a99dcd380c6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# ...
# WARNING: optimum-intel 1.27.0.dev0+07e3dd4 does not provide the extra 'dev'
# ...

# %%
# !pip install -q "transformers<=4.53.3"

# %%
# !pytest tests/openvino/test_export.py::ExportModelTest::test_export_requires_trust_remote_code_for_multimodal_models -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: typeguard-4.5.1, anyio-4.13.0, langsmith-0.7.34
# collected 1 item
#
# tests/openvino/test_export.py::ExportModelTest::test_export_requires_trust_remote_code_for_multimodal_models PASSED [100%]
#
# =============================== warnings summary ===============================
# tests/openvino/test_export.py::ExportModelTest::test_export_requires_trust_remote_code_for_multimodal_models
# ...

# %%
# !pytest tests/openvino/test_export.py -k trust_remote_code -vv -s
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: typeguard-4.5.1, anyio-4.13.0, langsmith-0.7.34
# collecting ... 2026-04-29 01:29:50.786610: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-29 01:29:50.870779: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Multiple distributions found for package optimum. Picked distribution: optimum
# ...

# %%
# !pytest tests/openvino/test_export.py -k trust_remote_code -vv --capture=no
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: typeguard-4.5.1, anyio-4.13.0, langsmith-0.7.34
# collecting ... 2026-04-29 02:10:08.294293: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-29 02:10:08.510306: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Multiple distributions found for package optimum. Picked distribution: optimum
# ...

# %% [markdown]
# 🔥 Caught exception:
# ValueError('The repository optimum-intel-internal-testing/tiny-random-nanollava contains custom code which must be executed to correctly load the model. You can inspect the repository content at https://hf.co/optimum-intel-internal-testing/tiny-random-nanollava .\n You can inspect the repository content at https://hf.co/optimum-intel-internal-testing/tiny-random-nanollava.\nPlease pass the argument `trust_remote_code=True` to allow custom code to be run.')
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# PASSED

# %%
# !pytest tests/openvino/test_export.py::ExportModelTest::test_export_requires_trust_remote_code_for_multimodal_models -vv --capture=no
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: typeguard-4.5.1, anyio-4.13.0, langsmith-0.7.34
# collecting ... 2026-04-29 03:53:55.690508: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-29 03:53:56.324121: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Multiple distributions found for package optimum. Picked distribution: optimum
# ...

# %%
# !pytest tests/openvino/test_export.py::ExportModelTest::test_export_requires_trust_remote_code_for_multimodal_models -vv --capture=no
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: typeguard-4.5.1, anyio-4.13.0, langsmith-0.7.34
# collecting ... 2026-04-29 04:00:23.157315: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-29 04:00:23.318528: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Multiple distributions found for package optimum. Picked distribution: optimum
# ...

# %%
# !pytest tests/openvino/test_export.py::ExportModelTest::test_export_requires_trust_remote_code_for_multimodal_models -vv --capture=no
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: typeguard-4.5.1, anyio-4.13.0, langsmith-0.7.34
# collecting ... 2026-04-29 04:23:17.483180: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-29 04:23:17.607469: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Multiple distributions found for package optimum. Picked distribution: optimum
# ...

# %%
# !pytest tests/openvino/test_export.py -k trust_remote_code -vv --capture=no
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: typeguard-4.5.1, anyio-4.13.0, langsmith-0.7.34
# collecting ... 2026-04-29 04:25:09.507382: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-29 04:25:09.579398: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Multiple distributions found for package optimum. Picked distribution: optimum
# ...

# %%
# !pytest tests/openvino/test_export.py -k trust_remote_code -vv --capture=no
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: typeguard-4.5.1, anyio-4.13.0, langsmith-0.7.34
# collecting ... 2026-04-29 04:55:58.241953: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-04-29 04:55:58.411383: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Multiple distributions found for package optimum. Picked distribution: optimum
# ...
