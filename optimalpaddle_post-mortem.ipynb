# %%
from transformers import AutoProcessor, AutoModelForImageTextToText

model = AutoModelForImageTextToText.from_pretrained("PaddlePaddle/PaddleOCR-VL", dtype="bfloat16")
processor = AutoProcessor.from_pretrained("PaddlePaddle/PaddleOCR-VL")
# Out:
# Unrecognized keys in `rope_parameters` for 'rope_type'='default': {'mrope_section'}
# Loading weights:   0%|          | 0/608 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/133 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/641 [00:00<?, ?B/s]
# The image processor of type `PaddleOCRVLImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# Unrecognized keys in `rope_parameters` for 'rope_type'='default': {'mrope_section'}
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.2M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/1.61M [00:00<?, ?B/s]
# ...

# %%
print(model)
# Out:
# PaddleOCRVLForConditionalGeneration(
#   (model): PaddleOCRVLModel(
#     (visual): PaddleOCRVisionModel(
#       (vision_model): PaddleOCRVisionTransformer(
#         (embeddings): PaddleOCRVisionEmbeddings(
#           (patch_embedding): Conv2d(3, 1152, kernel_size=(14, 14), stride=(14, 14), padding=valid)
#           (position_embedding): Embedding(729, 1152)
#         )
#         (encoder): PaddleOCRVisionEncoder(
#           (layers): ModuleList(
#             (0-26): 27 x PaddleOCRVisionEncoderLayer(
#               (layer_norm1): LayerNorm((1152,), eps=1e-06, elementwise_affine=True)
#               (self_attn): PaddleOCRVisionAttention(
#                 (k_proj): Linear(in_features=1152, out_features=1152, bias=True)
#                 (v_proj): Linear(in_features=1152, out_features=1152, bias=True)
#                 (q_proj): Linear(in_features=1152, out_features=1152, bias=True)
#                 (out_proj): Linear(in_features=1152, out_features=1152, bias=True)
# ...

# %%
! pip install -U "optimum-intel[openvino]"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.6/805.6 kB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 MB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 91.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.2/194.2 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 39.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.9/371.9 kB 26.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 28.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 57.5 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/MissLostCodes/optimum-intel.git
# %cd optimum-intel
# !git checkout feat/paddleocr-vl-openvino-support
# Out:
# Cloning into 'optimum-intel'...
# remote: Enumerating objects: 13127, done.
# remote: Counting objects: 100% (599/599), done.
# remote: Compressing objects: 100% (427/427), done.
# remote: Total 13127 (delta 475), reused 194 (delta 172), pack-reused 12528 (from 4)
# Receiving objects: 100% (13127/13127), 18.99 MiB | 22.02 MiB/s, done.
# Resolving deltas: 100% (8987/8987), done.
# /content/optimum-intel
# Branch 'feat/paddleocr-vl-openvino-support' set up to track remote branch 'feat/paddleocr-vl-openvino-support' from 'origin'.
# Switched to a new branch 'feat/paddleocr-vl-openvino-support'

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/optimum-intel
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/optimum-onnx.git (to revision main) to /tmp/pip-install-_xg_rlvf/optimum-onnx_85541184a55140e99dfa41ad44e2999a
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/optimum-onnx.git /tmp/pip-install-_xg_rlvf/optimum-onnx_85541184a55140e99dfa41ad44e2999a
#   Resolved https://github.com/huggingface/optimum-onnx.git to commit 3b33f43398b4e191a993474b8cfadc11d8e01ff2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/optimum to /tmp/pip-install-_xg_rlvf/optimum_4ad890b7efda454d92b7e93b9b643e17
# ...

# %%
# !optimum-cli export openvino \
  --model PaddlePaddle/PaddleOCR-VL \
  --task image-text-to-text \
  --trust-remote-code \
  output_dir
# Out:
# 2026-04-10 07:27:38.756857: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775806058.777692    9483 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775806058.784686    9483 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775806058.802176    9483 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
