# %%
# !git clone https://github.com/MissLostCodes/optimum-intel.git
# %cd optimum-intel
# !git checkout fix/openvino-respect-trust-remote-code
# Out:
# Cloning into 'optimum-intel'...
# remote: Enumerating objects: 13176, done.
# remote: Counting objects: 100% (578/578), done.
# remote: Compressing objects: 100% (313/313), done.
# remote: Total 13176 (delta 480), reused 274 (delta 265), pack-reused 12598 (from 3)
# Receiving objects: 100% (13176/13176), 18.98 MiB | 25.88 MiB/s, done.
# Resolving deltas: 100% (9007/9007), done.
# /content/optimum-intel
# Branch 'fix/openvino-respect-trust-remote-code' set up to track remote branch 'fix/openvino-respect-trust-remote-code' from 'origin'.
# Switched to a new branch 'fix/openvino-respect-trust-remote-code'

# %%
# !pip install -U pip
# !pip install -e .[dev]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 26.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
# Obtaining file:///content/optimum-intel
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Cloning https://github.com/huggingface/optimum-onnx.git (to revision main) to /tmp/pip-install-ece_os0c/optimum-onnx_8cfc66e8ea5d44e5944931ccf2a9c13c
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/optimum-onnx.git /tmp/pip-install-ece_os0c/optimum-onnx_8cfc66e8ea5d44e5944931ccf2a9c13c
#   Resolved https://github.com/huggingface/optimum-onnx.git to commit 3b33f43398b4e191a993474b8cfadc11d8e01ff2
#   Installing build dependencies ... done
# ...

# %%
# !pip install openvino openvino-genai

# %%
# !pip install parameterized

# %% [markdown]
# expoerter cli

# %%
# !pytest tests/openvino/test_exporters_cli.py::OVCLIExportTestCase::test_exporters_cli_4bit_02_text_generation_with_past -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 1 item
#
# tests/openvino/test_exporters_cli.py::OVCLIExportTestCase::test_exporters_cli_4bit_02_text_generation_with_past FAILED [100%]
#
# =================================== FAILURES ===================================
# ___ OVCLIExportTestCase.test_exporters_cli_4bit_02_text_generation_with_past ___
#
# a = (<test_exporters_cli.OVCLIExportTestCase testMethod=test_exporters_cli_4bit_02_text_generation_with_past>,)
# kw = {}
#
#     @wraps(func)
#     def standalone_func(*a, **kw):
# >       return func(*(a + p.args), **p.kwargs, **kw)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ...

# %%
# !pytest tests/openvino/test_exporters_cli.py::OVCLIExportTestCase::test_exporters_cli_full_quantization_10_feature_extraction -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 1 item
#
# tests/openvino/test_exporters_cli.py::OVCLIExportTestCase::test_exporters_cli_full_quantization_10_feature_extraction PASSED [100%]
#
# ============================== 1 passed in 55.07s ==============================

# %%
# !pytest tests/openvino/test_exporters_cli.py::OVCLIExportTestCase::test_exporters_cli_sentence_transformers -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 1 item
#
# tests/openvino/test_exporters_cli.py::OVCLIExportTestCase::test_exporters_cli_sentence_transformers PASSED [100%]
#
# ======================== 1 passed in 107.26s (0:01:47) =========================

# %% [markdown]
# Decoder failures

# %%
# !pytest tests/openvino/test_decoder.py::OVModelForCausalLMIntegrationTest::test_compare_to_transformers_30_xglm -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 1 item
#
# tests/openvino/test_decoder.py::OVModelForCausalLMIntegrationTest::test_compare_to_transformers_30_xglm PASSED [100%]
#
# =============================== warnings summary ===============================
# ../../usr/lib/python3.12/multiprocessing/popen_fork.py:66
# tests/openvino/test_decoder.py::OVModelForCausalLMIntegrationTest::test_compare_to_transformers_30_xglm
#   /usr/lib/python3.12/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#     self.pid = os.fork()
#
# ...

# %%
# !pytest tests/openvino/test_decoder.py::OVModelForCausalLMIntegrationTest::test_compare_to_transformers_52_zamba2 -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 1 item
#
# tests/openvino/test_decoder.py::OVModelForCausalLMIntegrationTest::test_compare_to_transformers_52_zamba2 PASSED [100%]
#
# =============================== warnings summary ===============================
# ../../usr/lib/python3.12/multiprocessing/popen_fork.py:66
# tests/openvino/test_decoder.py::OVModelForCausalLMIntegrationTest::test_compare_to_transformers_52_zamba2
#   /usr/lib/python3.12/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#     self.pid = os.fork()
#
# ...

# %%
# !pytest tests/openvino/test_decoder.py::OVModelForCausalLMIntegrationTest::test_compare_to_transformers_53_granitemoehybrid -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 1 item
#
# tests/openvino/test_decoder.py::OVModelForCausalLMIntegrationTest::test_compare_to_transformers_53_granitemoehybrid PASSED [100%]
#
# =============================== warnings summary ===============================
# ../../usr/lib/python3.12/multiprocessing/popen_fork.py:66
# tests/openvino/test_decoder.py::OVModelForCausalLMIntegrationTest::test_compare_to_transformers_53_granitemoehybrid
#   /usr/lib/python3.12/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#     self.pid = os.fork()
#
# ...

# %% [markdown]
# ## this mf failed

# %%
# !pytest tests/openvino/test_decoder.py::OVModelForCausalLMIntegrationTest::test_compare_to_transformers_62_llama4 -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 1 item
#
# tests/openvino/test_decoder.py::OVModelForCausalLMIntegrationTest::test_compare_to_transformers_62_llama4 FAILED [100%]
#
# =================================== FAILURES ===================================
# ___ OVModelForCausalLMIntegrationTest.test_compare_to_transformers_62_llama4 ___
#
# a = (<test_decoder.OVModelForCausalLMIntegrationTest testMethod=test_compare_to_transformers_62_llama4>,)
# kw = {}
#
#     @wraps(func)
#     def standalone_func(*a, **kw):
# >       return func(*(a + p.args), **p.kwargs, **kw)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# /usr/local/lib/python3.12/dist-packages/parameterized/parameterized.py:620:
# ...

# %% [markdown]
# seq2seq

# %%
# !pytest tests/openvino/test_seq2seq.py::OVModelForVisualCausalLMIntegrationTest::test_compare_to_transformers_11_llama4 -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 0 items
#
# ============================ no tests ran in 19.31s ============================
# ERROR: not found: /content/optimum-intel/tests/openvino/test_seq2seq.py::OVModelForVisualCausalLMIntegrationTest::test_compare_to_transformers_11_llama4
# (no match in any of [<UnitTestCase OVModelForVisualCausalLMIntegrationTest>])

# %% [markdown]
# quatization

# %%
# !pytest tests/openvino/test_quantization.py::OVQuantizerTest::test_ov_model_static_quantization_with_auto_dataset_07 -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 1 item
#
# tests/openvino/test_quantization.py::OVQuantizerTest::test_ov_model_static_quantization_with_auto_dataset_07 PASSED [100%]
#
# =============================== warnings summary ===============================
# tests/openvino/test_quantization.py::OVQuantizerTest::test_ov_model_static_quantization_with_auto_dataset_07
# ...

# %%
# !pytest tests/openvino/test_quantization.py::OVQuantizerTest::test_ovmodel_static_quantization_04 -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 1 item
#
# tests/openvino/test_quantization.py::OVQuantizerTest::test_ovmodel_static_quantization_04 PASSED [100%]
#
# =============================== warnings summary ===============================
# tests/openvino/test_quantization.py::OVQuantizerTest::test_ovmodel_static_quantization_04
# ...

# %%
# !pytest tests/openvino/test_quantization.py::OVQuantizerTest::test_ovmodel_static_quantization_05 -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 1 item
#
# tests/openvino/test_quantization.py::OVQuantizerTest::test_ovmodel_static_quantization_05 PASSED [100%]
#
# =============================== warnings summary ===============================
# tests/openvino/test_quantization.py::OVQuantizerTest::test_ovmodel_static_quantization_05
# ...

# %%
# !pytest tests/openvino/test_quantization.py::OVWeightCompressionTest::test_ovmodel_4bit_auto_compression_with_config_01 -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 1 item
#
# tests/openvino/test_quantization.py::OVWeightCompressionTest::test_ovmodel_4bit_auto_compression_with_config_01 FAILED [100%]
#
# =================================== FAILURES ===================================
# __ OVWeightCompressionTest.test_ovmodel_4bit_auto_compression_with_config_01 ___
#
# a = (<test_quantization.OVWeightCompressionTest testMethod=test_ovmodel_4bit_auto_compression_with_config_01>,)
# kw = {}
#
#     @wraps(func)
#     def standalone_func(*a, **kw):
# >       return func(*(a + p.args), **p.kwargs, **kw)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# ...

# %% [markdown]
# genai

# %%
# !pytest tests/openvino/test_genai.py -k "xglm or llama4 or granitemoe" -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 56 items / 54 deselected / 2 selected
#
# tests/openvino/test_genai.py::LLMPipelineTestCase::test_compare_outputs_15_xglm PASSED [ 50%]
# tests/openvino/test_genai.py::LLMPipelineTestCase::test_compare_outputs_33_granitemoe PASSED [100%]
#
# =============================== warnings summary ===============================
# optimum/intel/openvino/modeling_base.py:590
#   /content/optimum-intel/optimum/intel/openvino/modeling_base.py:590: SyntaxWarning: invalid escape sequence '\.'
#     pattern=cls._search_pattern if not kwargs.get("from_onnx", False) else ".*\.onnx$",
#
# tests/openvino/test_genai.py::LLMPipelineTestCase::test_compare_outputs_15_xglm
# ...

# %%
# !pytest tests/openvino/test_genai.py -v
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/optimum-intel
# configfile: pyproject.toml
# plugins: anyio-4.13.0, typeguard-4.5.1, langsmith-0.7.23
# collected 56 items
#
# tests/openvino/test_genai.py::LLMPipelineTestCase::test_compare_outputs_00_gpt_bigcode PASSED [  1%]
# tests/openvino/test_genai.py::LLMPipelineTestCase::test_compare_outputs_01_bloom PASSED [  3%]
# tests/openvino/test_genai.py::LLMPipelineTestCase::test_compare_outputs_02_codegen PASSED [  5%]
# tests/openvino/test_genai.py::LLMPipelineTestCase::test_compare_outputs_03_codegen2 PASSED [  7%]
# tests/openvino/test_genai.py::LLMPipelineTestCase::test_compare_outputs_04_gpt2 PASSED [  8%]
# tests/openvino/test_genai.py::LLMPipelineTestCase::test_compare_outputs_05_gptj PASSED [ 10%]
# ...

# %%
# !pytest tests/openvino/test_decoder.py -v
# !pytest tests/openvino/test_seq2seq.py -v
# !pytest tests/openvino/test_exporters_cli.py -v

# %%
# clone upstream repo
# !git clone https://github.com/huggingface/optimum-intel.git
# %cd optimum-intel

# fetch the PR
# !git fetch origin pull/1673/head:pr-1673

# checkout PR
# !git checkout pr-1673
# Out:
# Cloning into 'optimum-intel'...
# remote: Enumerating objects: 15440, done.
# remote: Counting objects: 100% (1207/1207), done.
# remote: Compressing objects: 100% (439/439), done.
# remote: Total 15440 (delta 1088), reused 771 (delta 768), pack-reused 14233 (from 3)
# Receiving objects: 100% (15440/15440), 19.31 MiB | 25.55 MiB/s, done.
# Resolving deltas: 100% (10512/10512), done.
# /content/optimum-intel/optimum-intel
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 37 (delta 12), reused 13 (delta 9), pack-reused 16 (from 1)
# Unpacking objects: 100% (37/37), 50.26 KiB | 1.05 MiB/s, done.
# From https://github.com/huggingface/optimum-intel
#  * [new ref]         refs/pull/1673/head -> pr-1673
# Switched to branch 'pr-1673'

# %%
# !git diff origin/main...pr-1673
# Out:
# diff --git a/optimum/exporters/openvino/__main__.py b/optimum/exporters/openvino/__main__.py
# index eb763b4..f299d9b 100644
# --- a/optimum/exporters/openvino/__main__.py
# +++ b/optimum/exporters/openvino/__main__.py
# @@ -112,6 +112,13 @@ def infer_task(
#                  )
#
#      if library_name == "transformers":
# +        if not trust_remote_code:
# +            logger.warning(
# +                "This model may require executing custom code from its repository. "
# +                "For security reasons, this is disabled by default. "
# +                "Please review the source and rerun with `--trust-remote-code` if needed."
# +            )
# +
#          config = AutoConfig.from_pretrained(
#              model_name_or_path,
#              subfolder=subfolder,
# diff --git a/optimum/exporters/openvino/convert.py b/optimum/exporters/openvino/convert.py
# index 60d90f5..cd440e9 100644
# --- a/optimum/exporters/openvino/convert.py
# ...
